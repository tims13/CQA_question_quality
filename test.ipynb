# %%
import numpy as np
import pandas as pd

# %%
data_path = 'UltimateDataset/result1124.csv'

# %%
data = pd.read_csv(data_path)

# %%
data.describe()
# Out:
#          QuestionId         Score   AnswerCount      ViewCount  FavoriteCount  \
# count  4.067800e+04  40678.000000  40678.000000   40678.000000    6072.000000
# mean   4.592335e+07      0.680859      0.974507     657.345346       1.177866
# std    7.369567e+06      2.935578      0.977241    2536.479541       2.134418
# min    3.279480e+07    -23.000000      0.000000       6.000000       0.000000
# 25%    4.067657e+07      0.000000      0.000000      60.000000       1.000000
# 50%    4.850571e+07      0.000000      1.000000     172.000000       1.000000
# 75%    4.901765e+07      1.000000      1.000000     548.000000       1.000000
# max    5.699102e+07    192.000000     17.000000  161579.000000     110.000000
#
#        LastEditorUserId  RealReputation  QuestionerId  \
# count      2.213700e+04    40678.000000  4.067800e+04
# mean       3.789548e+06     1782.004695  5.024898e+06
# std        2.985635e+06     9982.175916  2.802793e+06
# ...
